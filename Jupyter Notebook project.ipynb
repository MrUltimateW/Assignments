# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Christian Flisar__
#
# Data Scientist

# %% [markdown]
# _As we live in the age of constant, high volume data production, the know-how in dealing with Big Data is more valuable than ever, no matter what area of our life and profession we are talking about_

# %% [markdown]
# ### The following code determines from a number whether it is even or odd

# %%
def evenorodd(n):
    
    if  (n%2) == 0:
        print ('This is an even number')
    else:
        print('This is an odd number')

evenorodd(4)
# Out:
# This is an even number

# %% [markdown]
# 1. cat
# 2. dog
# 3. bird
# ***
# ![GettyImages-1140602972-e1651249657746.jpg](attachment:GettyImages-1140602972-e1651249657746.jpg)
